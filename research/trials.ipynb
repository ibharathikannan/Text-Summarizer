# %% [markdown]
# # ConfigBox - To use the dist using . (dot operator)

# %%
from box import ConfigBox
d2 = ConfigBox({"name": "Krish", "age": 30, "city": "Chennai"})
print(d2.name)
# Out:
# Krish

# %% [markdown]
# # @ensure_annotations - to ensure the data type of the object parameter is same as function defination
